# %% [markdown]
# **Import the nessassary libraries**

# %%
import rioxarray as rxr
import pandas as pd
import zipfile
from pathlib import Path

# %% [markdown]
# **Creating the nessassary folders**

# %%
zip_path = "path/to/your_rasters.zip"

extract_dir = Path("temp_rasters")
